# %% [markdown]
# <a href="https://colab.research.google.com/github/QustaB/learning_with_Axsos/blob/main/Qusta_Central_tendency_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lists of Fahrenheit temps
week_1=[45,55,49,60,52,55,58]
week_2=[51,49,62,50,53,56,59]
week_3=[60,60,61,62,57,59,58]
week_4=[59,63,62,61,65,66,62]

# %%
import numpy as np
from statistics import mode

# %%
print(np.mean(week_1))
print(np.median(week_1))
print(mode(week_1))
# Out:
# 53.42857142857143
# 55.0
# 55

# %%
def central_tendency(week,verbose=True):
    mean_temp=round(float(np.mean(week)),2)
    median_temp=round(float(np.median(week)),2)
    mode_temp=round(float(mode(week)),2)
    if verbose==True:
        print(f'The mean is {mean_temp}')
        print(f'The median is {median_temp}')
        print(f'The mode is {mode_temp}')
    else:
        return [mean_temp,median_temp,mode_temp]

# %%
central_tendency(week_1)
# Out:
# The mean is 53.43
# The median is 55.0
# The mode is 55.0

# %%
central_tendency(week_2,True)
central_tendency(week_2)
central_tendency(week_2,False)
# Out:
# The mean is 54.29
# The median is 53.0
# The mode is 51.0
# The mean is 54.29
# The median is 53.0
# The mode is 51.0
# [54.29, 53.0, 51.0]
